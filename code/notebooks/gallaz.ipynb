# %%
# %load_ext autoreload
# %autoreload 2
from modules.sophrosyne import SimulationRunner, ShimizuMorioka2, Plotter
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
runner = SimulationRunner(
    system_cls=ShimizuMorioka2,
    system_params={"a": 1.5, "b": 0.1},
    N=100,
    epsilon=0.5,
    dt=0.05,
    steps=50000,
    window=1000,
    threshold=10000
)
result = runner.run()
# Out:
#     ╔══════════════════════════════════════╗
#     ║             SOPHROSYNE               ║
#     ║              v1.0.0                  ║
#     ║   Coupled Dynamical Systems Solver   ║
#     ║            by R.S.S.G.               ║
#     ╚══════════════════════════════════════╝
#
# System   : ShimizuMorioka2(ε=0.5, a=1.5, b=0.1)
# N=100, ε=0.5, dt=0.05, steps=50000, threshold=10000
# Window=1000, save_full=False
# --------------------------------------------------
#   [ 10.0%] step     5000/50000  (0.7s elapsed)
#   [ 20.0%] step    10000/50000  (1.4s elapsed)
#   [ 30.0%] step    15000/50000  (2.0s elapsed)
#   [ 40.0%] step    20000/50000  (2.7s elapsed)
#   [ 50.0%] step    25000/50000  (3.4s elapsed)
#   [ 60.0%] step    30000/50000  (4.0s elapsed)
#   [ 70.0%] step    35000/50000  (4.7s elapsed)
#   [ 80.0%] step    40000/50000  (5.4s elapsed)
#   [ 90.0%] step    45000/50000  (6.1s elapsed)
#   [100.0%] step    50000/50000  (6.8s elapsed)
#
# Completed 50000 steps in 6.79s
# ...

# %%
Plotter.plot_all(result=result, output_dir="./../../outputs/gallaz")
# Out:
# Saved plot → ./../../outputs/gallaz/ShimizuMorioka2_N100_e0p5_tail_timeseries.png
# Saved plot → ./../../outputs/gallaz/ShimizuMorioka2_N100_e0p5_attractor_3d.png
# Saved plot → ./../../outputs/gallaz/ShimizuMorioka2_N100_e0p5_sigma.png
