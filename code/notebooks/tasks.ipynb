# %% [markdown]
# # Tasks
#
# ### Date: 21/02/2026
# ### Name: Rolando Sánchez

# %%
import modules.tent as tent

# %%
# ═══════════════════════════════════════════
# PARAMETERS — change these
# ═══════════════════════════════════════════
A   = 3    # tent map parameter
EPS = 0.45     # coupling strength

print(f"\n{'=' * 60}")
print(f"  GLOBALLY COUPLED TENT MAPS: a={A}, eps={EPS}")
print(f"{'=' * 60}\n")

tent.analysis_timeseries(EPS, A)
# Out:
# ...
#   GLOBALLY COUPLED TENT MAPS: a=3, eps=0.45
# ...
#
# ...
# ANALYSIS 1: Time series of h_t  (eps=0.45, a=3)
# ...
#   -> Saved fig1_timeseries.png

# %%
tent.analysis_fluctuation_scaling(EPS, A)
# Out:
# ...
# ANALYSIS 2: Fluctuation scaling  (eps=0.45, a=3)
# ...
#   N=  1000:  <h> = 0.647129,  sigma_h = 0.092519
#   N= 10000:  <h> = 0.647752,  sigma_h = 0.092056
#   N=100000:  <h> = 0.648390,  sigma_h = 0.091864
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tent.analysis_fluctuation_scaling(EPS, A)
#
# File ~/Documents/Yachay/sophrosyne/sophrosyne/results/20_02_26/tent.py:92, in analysis_fluctuation_scaling(eps, a)
#      90 trial_means = []
#      91 for trial in range(n_trials):
# ---> 92     h = simulate(N, eps, a, T_total=8000, T_transient=3000, seed=42 + trial)
#      93     trial_sigmas.append(np.std(h))
#      94     trial_means.append(np.mean(h))
#
# File ~/Documents/Yachay/sophrosyne/sophrosyne/results/20_02_26/tent.py:37, in simulate(N, eps, a, T_total, T_transient, seed)
#      35 for t in range(T_total):
#      36     fx = tent(x, a)
# ...

# %%
tent.analysis_distribution(EPS, A)
# Out:
# ...
# ANALYSIS 3: Distribution & rescaled collapse  (eps=0.45, a=3)
# ...
#   N=  1000: <h>=0.647162, sigma=0.092340, Shapiro p=0.0000
#   N= 10000: <h>=0.647734, sigma=0.091979, Shapiro p=0.0000
#   N=100000: <h>=0.648421, sigma=0.091816, Shapiro p=0.0000
#   N=1000000: <h>=0.648612, sigma=0.091477, Shapiro p=0.0000
#   N=10000000: <h>=0.648636, sigma=0.091431, Shapiro p=0.0000
#   -> Saved fig3_distribution.png

# %%
tent.analysis_self_consistency(EPS, A)
# Out:
# ...
# ANALYSIS 4: Self-consistency  (eps=0.45, a=3)
# ...
#   Self-consistent h_bar: [np.float64(0.6569335555641135)]
#   Simulation <h> (N=10000): 0.647753
#   |diff| = 0.009181
#   -> Saved fig4_self_consistency.png

# %%
tent.analysis_phase_diagram(A)
# Out:
# ...
# ANALYSIS 5: Phase diagram alpha(eps)  (a=3)
# ...
#   eps=0.02:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.05:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.08:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.11:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.14:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.17:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.20:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.23:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.26:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.29:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.32:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.35:  alpha = nan +/- nan  (R^2=nan)
#   eps=0.38:  alpha = 0.1540 +/- 0.0456  (R^2=0.7918)
#   eps=0.41:  alpha = 0.4224 +/- 0.0382  (R^2=0.9760)
#   eps=0.44:  alpha = -0.0100 +/- 0.0019  (R^2=0.9032)
#   eps=0.47:  alpha = 0.0044 +/- 0.0023  (R^2=0.5570)
#   eps=0.50:  alpha = 0.0183 +/- 0.0092  (R^2=0.5705)
# ---------------------------------------------------------------------------
# ...

# %%
import tent
tent.bifurcation_diagram(bifurcation_param='a', eps_fixed=0.1, h_bar=0.65)
tent.bifurcation_diagram(bifurcation_param='eps', a_fixed=3, h_bar=0.65)

# %%
import tent
# ═══════════════════════════════════════════
# PARAMETERS — change these
# ═══════════════════════════════════════════
A   = 2.2    # tent map parameter
EPS = 0.3     # coupling strength

print(f"\n{'=' * 60}")
print(f"  GLOBALLY COUPLED TENT MAPS: a={A}, eps={EPS}")
print(f"{'=' * 60}\n")

tent.analysis_timeseries(EPS, A)
tent.analysis_fluctuation_scaling(EPS, A)
tent.analysis_distribution(EPS, A)
tent.analysis_self_consistency(EPS, A)
tent.analysis_phase_diagram(A)
tent.bifurcation_diagram(bifurcation_param='a', eps_fixed=0.3, h_bar=0.65)
tent.bifurcation_diagram(bifurcation_param='eps', a_fixed=2.2, h_bar=0.65)
# Out:
# ...
#   GLOBALLY COUPLED TENT MAPS: a=2.2, eps=0.3
# ...
#
# ...
# ANALYSIS 1: Time series of h_t  (eps=0.3, a=2.2)
# ...
#   -> Saved fig1_timeseries.png
#
# ...
# ANALYSIS 2: Fluctuation scaling  (eps=0.3, a=2.2)
# ...
#   N=   100:  <h> = 0.642863,  sigma_h = 0.038271
#   N=   500:  <h> = 0.644580,  sigma_h = 0.019413
#   N=  1000:  <h> = 0.644841,  sigma_h = 0.014811
#   N=  5000:  <h> = 0.645168,  sigma_h = 0.007212
#   N= 10000:  <h> = 0.645203,  sigma_h = 0.005920
#   N= 50000:  <h> = 0.645238,  sigma_h = 0.004134
#   N=100000:  <h> = 0.645244,  sigma_h = 0.003940
#
#   Log-log fit:  sigma_h ~ N^-0.3381  (R^2 = 0.969982)
#   Expected: -0.5000,  Deviation: 0.1619
#   -> Saved fig2_scaling.png
#
# ...
# ANALYSIS 3: Distribution & rescaled collapse  (eps=0.3, a=2.2)
# ...
#   N=   500: <h>=0.644565, sigma=0.019507, Shapiro p=0.0125
#   N=  1000: <h>=0.644849, sigma=0.014560, Shapiro p=0.0036
#   N=  5000: <h>=0.645167, sigma=0.007191, Shapiro p=0.0003
#   N=100000: <h>=0.645245, sigma=0.003875, Shapiro p=0.0000
# ...

# %%
import tent
# ═══════════════════════════════════════════
# PARAMETERS — change these
# ═══════════════════════════════════════════
A   = 2    # tent map parameter
EPS = 0.3     # coupling strength

print(f"\n{'=' * 60}")
print(f"  GLOBALLY COUPLED TENT MAPS: a={A}, eps={EPS}")
print(f"{'=' * 60}\n")

tent.analysis_timeseries(EPS, A)
tent.analysis_fluctuation_scaling(EPS, A)
tent.analysis_distribution(EPS, A)
tent.analysis_self_consistency(EPS, A)
tent.analysis_phase_diagram(A)
tent.bifurcation_diagram(bifurcation_param='a', eps_fixed=0.3, h_bar=0.638)
tent.bifurcation_diagram(bifurcation_param='eps', a_fixed=2, h_bar=0.638)
# Out:
# ...
#   GLOBALLY COUPLED TENT MAPS: a=2, eps=0.3
# ...
#
# ...
# ANALYSIS 1: Time series of h_t  (eps=0.3, a=2)
# ...
#   -> Saved fig1_timeseries.png
#
# ...
# ANALYSIS 2: Fluctuation scaling  (eps=0.3, a=2)
# ...
#   N=   100:  <h> = 0.638521,  sigma_h = 0.033536
#   N=   500:  <h> = 0.634390,  sigma_h = 0.068969
#   N=  1000:  <h> = 0.630771,  sigma_h = 0.086494
#   N=  5000:  <h> = 0.638082,  sigma_h = 0.018824
#   N= 10000:  <h> = 0.638082,  sigma_h = 0.018375
#   N= 50000:  <h> = 0.638027,  sigma_h = 0.018597
#   N=100000:  <h> = 0.638002,  sigma_h = 0.018877
#
#   Log-log fit:  sigma_h ~ N^-0.1830  (R^2 = 0.460442)
#   Expected: -0.5000,  Deviation: 0.3170
#   -> Saved fig2_scaling.png
#
# ...
# ANALYSIS 3: Distribution & rescaled collapse  (eps=0.3, a=2)
# ...
#   N=   500: <h>=0.633666, sigma=0.074858, Shapiro p=0.0000
#   N=  1000: <h>=0.627709, sigma=0.108733, Shapiro p=0.0000
#   N=  5000: <h>=0.638123, sigma=0.017978, Shapiro p=0.0000
#   N=100000: <h>=0.637994, sigma=0.019069, Shapiro p=0.0000
# ...

# %%
# ═══════════════════════════════════════════
# PARAMETERS — change these
# ═══════════════════════════════════════════
A   = 1.99   # tent map parameter
EPS = 0.1    # coupling strength

print(f"\n{'=' * 60}")
print(f"  GLOBALLY COUPLED TENT MAPS: a={A}, eps={EPS}")
print(f"{'=' * 60}\n")

tent.analysis_timeseries(EPS, A)
tent.analysis_fluctuation_scaling(EPS, A)
tent.analysis_distribution(EPS, A)
tent.analysis_self_consistency(EPS, A)
tent.analysis_phase_diagram(A)
# Out:
# ...
#   GLOBALLY COUPLED TENT MAPS: a=1.99, eps=0.1
# ...
#
# ...
# ANALYSIS 1: Time series of h_t  (eps=0.1, a=1.99)
# ...
#   -> Saved fig1_timeseries.png
#
# ...
# ANALYSIS 2: Fluctuation scaling  (eps=0.1, a=1.99)
# ...
#   N=   100:  <h> = 0.587868,  sigma_h = 0.025246
#   N=   500:  <h> = 0.588332,  sigma_h = 0.011335
#   N=  1000:  <h> = 0.588471,  sigma_h = 0.008068
#   N=  5000:  <h> = 0.588493,  sigma_h = 0.003605
#   N= 10000:  <h> = 0.588468,  sigma_h = 0.002539
#   N= 50000:  <h> = 0.588474,  sigma_h = 0.001149
#   N=100000:  <h> = 0.588473,  sigma_h = 0.000804
#
#   Log-log fit:  sigma_h ~ N^-0.4985  (R^2 = 0.999988)
#   Expected: -0.5000,  Deviation: 0.0015
#   -> Saved fig2_scaling.png
#
# ...
# ANALYSIS 3: Distribution & rescaled collapse  (eps=0.1, a=1.99)
# ...
#   N=   500: <h>=0.588318, sigma=0.011242, Shapiro p=0.0968
#   N=  1000: <h>=0.588466, sigma=0.008069, Shapiro p=0.2813
#   N=  5000: <h>=0.588463, sigma=0.003585, Shapiro p=0.8048
#   N=100000: <h>=0.588471, sigma=0.000814, Shapiro p=0.1021
# ...

# %%
tent.bifurcation_diagram(bifurcation_param='a', eps_fixed=0.1, h_bar=0.65)
tent.bifurcation_diagram(bifurcation_param='eps', a_fixed=1.99, h_bar=0.65)

# %%
tent.bifurcation_diagram(bifurcation_param='a', eps_fixed=0.4, h_bar=0.623)
tent.bifurcation_diagram(bifurcation_param='eps', a_fixed=3, h_bar=0.65)
